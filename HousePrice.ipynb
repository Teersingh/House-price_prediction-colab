# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
house=pd.read_csv('/content/House_Data.csv')

# %%
house.head()
# Out:
#          zpid          city          streetAddress  zipcode  \
# 0   111373431  pflugerville   14424 Lake Victor Dr    78660
# 1   120900430  pflugerville     1104 Strickling Dr    78660
# 2  2084491383  pflugerville    1408 Fort Dessau Rd    78660
# 3   120901374  pflugerville     1025 Strickling Dr    78660
# 4    60134862  pflugerville  15005 Donna Jane Loop    78660
#
#                                          description   latitude  longitude  \
# 0  14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632 -97.663078
# 1  Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432673 -97.661697
# 2  Under construction - estimated completion in A...  30.409748 -97.639771
# 3  Absolutely darling one story home in charming ...  30.432112 -97.661659
# 4  Brimming with appeal & warm livability! Sleek ...  30.437368 -97.656860
#
#    propertyTaxRate  garageSpaces  hasAssociation  ...  numOfMiddleSchools  \
# 0             1.98             2            True  ...                 1.0
# ...

# %%
house.columns
# Out:
# Index(['zpid', 'city', 'streetAddress', 'zipcode', 'description', 'latitude',
#        'longitude', 'propertyTaxRate', 'garageSpaces', 'hasAssociation',
#        'hasCooling', 'hasGarage', 'hasHeating', 'hasSpa', 'hasView',
#        'homeType', 'parkingSpaces', 'yearBuilt', 'latestPrice',
#        'numPriceChanges', 'latest_saledate', 'latest_salemonth',
#        'latest_saleyear', 'latestPriceSource', 'numOfPhotos',
#        'numOfAccessibilityFeatures', 'numOfAppliances', 'numOfParkingFeatures',
#        'numOfPatioAndPorchFeatures', 'numOfSecurityFeatures',
#        'numOfWaterfrontFeatures', 'numOfWindowFeatures',
#        'numOfCommunityFeatures', 'lotSizeSqFt', 'livingAreaSqFt',
#        'numOfPrimarySchools', 'numOfElementarySchools', 'numOfMiddleSchools',
#        'numOfHighSchools', 'avgSchoolDistance', 'avgSchoolRating',
#        'avgSchoolSize', 'MedianStudentsPerTeacher', 'numOfBathrooms',
#        'numOfBedrooms', 'numOfStories', 'homeImage'],
#       dtype='object')

# %%
house.latestPrice.head()
# Out:
# 0    305000.0
# 1    295000.0
# 2    256125.0
# 3    240000.0
# 4    239900.0
# Name: latestPrice, dtype: float64

# %% [markdown]
# Build a mean Regression model

# %%
# The simplest way to build mean regresssion model is calculate the mean of that particular target column

# %%
mean_regrssion=house['latestPrice'].mean

# %%
house['mean_price']=house['latestPrice'].mean
house['mean_price'].head()
# Out:
# 0    <bound method NDFrame._add_numeric_operations....
# 1    <bound method NDFrame._add_numeric_operations....
# 2    <bound method NDFrame._add_numeric_operations....
# 3    <bound method NDFrame._add_numeric_operations....
# 4    <bound method NDFrame._add_numeric_operations....
# Name: mean_price, dtype: object

# %%
house['latestPrice'].head()
# Out:
# 0    305000.0
# 1    295000.0
# 2    256125.0
# 3    240000.0
# 4    239900.0
# Name: latestPrice, dtype: float64

# %%
house['price_mean']=house['latestPrice'].mean()

# %%
house['price_mean'].head()
# Out:
# 0    495219.17173
# 1    495219.17173
# 2    495219.17173
# 3    495219.17173
# 4    495219.17173
# Name: price_mean, dtype: float64

# %%
# Visualize the mean regrssion model

# %%
# for this we will use the matplotlib library of python
plt.figure(dpi=100)
k=range(0,len(house))
plt.scatter(k,house['latestPrice'].sort_values(),color='red',label='Actual Price of house')
plt.plot(k,house['price_mean'].sort_values(),color='green',label='prediction price of house')
plt.xlabel('fitted point (Ascending)')
plt.ylabel('latestPrice')
plt.title('overall Mean')
plt.legend()

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10698 entries, 0 to 10697
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   zpid                        10698 non-null  int64
#  1   city                        10698 non-null  object
#  2   streetAddress               10698 non-null  object
#  3   zipcode                     10698 non-null  int64
#  4   description                 10698 non-null  object
#  5   latitude                    10698 non-null  float64
#  6   longitude                   10698 non-null  float64
#  7   propertyTaxRate             10698 non-null  float64
#  8   garageSpaces                10698 non-null  int64
#  9   hasAssociation              10698 non-null  bool
#  10  hasCooling                  10698 non-null  bool
#  11  hasGarage                   10698 non-null  bool
#  12  hasHeating                  10698 non-null  bool
# ...
